# %% [markdown]
# <a href="https://colab.research.google.com/github/hannahzzq/hannahzzq/blob/master/ESG_Factors_Combine_to_One_Table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Link + Libraries

# %%
 from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Basic Libraries
import os
import glob
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
import datetime
sb.set() # set the default Seaborn style for graphics
# %matplotlib inline
# #显示所有列
# pd.set_option('display.max_columns', None)
# #显示所有行
# pd.set_option('display.max_rows', None)

# %% [markdown]
# ## For EE Data, Create ESG_E_E_Total

# %%
## Read All ESG_E_Emissions Data Excel Files

local_path = r'/content/drive/My Drive/ESG_Data/E_Emissions'
filenames = glob.glob(local_path + "/*.xlsx")

dfnames = list()

for i in range(len(filenames)):
  dfnames.append(os.path.basename(filenames[i]))
  dfnames[i] = dfnames[i][:-5]

dfs = [pd.read_excel(filename) for filename in filenames]
for m in range(len(filenames)):
  dfs[m].columns=['Company_Code','Company_Name',dfnames[m]+'11', dfnames[m]+'12', dfnames[m]+'13', dfnames[m]+'14', dfnames[m]+'15', dfnames[m]+'16', dfnames[m]+'17', dfnames[m]+'18', dfnames[m]+'19', dfnames[m]+'20']
  dfs[m].drop(dfs[m].head(2).index,inplace=True)
  dfs[m] = dfs[m].drop(columns=['Company_Name'])
  dfs[m] = dfs[m].reset_index()
  dfs[m].drop(['index'],axis=1,inplace=True)

close_price = pd.read_excel("/content/drive/My Drive/ESG_Data/SP500_Price/Price_Close_Clear_dt.xlsx")
# Find index we need to drop (the company do not have data on or before 2011)
print(close_price.index[np.where(np.isnan(close_price[datetime.datetime(2010, 12, 31, 0, 0)]))[0]])
# Out:
# Int64Index([  1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
#             139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
#             223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
#             345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504],
#            dtype='int64')

# %%
# ESG_E_E Value for 2011-12-30 (Year 2011)
EE2011 = pd.DataFrame()
EE2011['Company_Code'] = dfs[0]['Company_Code'] 
EE2011['Date'] = '2011-12-30'
order = ['Date','Company_Code']
EE2011 = EE2011[order]

for n in range(len(filenames)):
  EE2011[dfnames[n]] = dfs[n][dfnames[n]+'11']

#Drop SP500 Companies which Do not have data on or before 2011
EE2011 = EE2011.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EE2011 = EE2011.reset_index()
EE2011.drop(['index'],axis=1,inplace=True)

# ESG_E_E Value for 2012-12-31 (Year 2012)
EE2012 = pd.DataFrame()
EE2012['Company_Code'] = dfs[0]['Company_Code'] 
EE2012['Date'] = '2012-12-31'
order = ['Date','Company_Code']
EE2012 = EE2012[order]

for n in range(len(filenames)):
  EE2012[dfnames[n]] = dfs[n][dfnames[n]+'12']

EE2012 = EE2012.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EE2012 = EE2012.reset_index()
EE2012.drop(['index'],axis=1,inplace=True)

# ESG_E_E Value for 2013-12-31 (Year 2013)
EE2013 = pd.DataFrame()
EE2013['Company_Code'] = dfs[0]['Company_Code'] 
EE2013['Date'] = '2013-12-31'
order = ['Date','Company_Code']
EE2013 = EE2013[order]

for n in range(len(filenames)):
  EE2013[dfnames[n]] = dfs[n][dfnames[n]+'13']

EE2013 = EE2013.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EE2013 = EE2013.reset_index()
EE2013.drop(['index'],axis=1,inplace=True)

# ESG_E_E Value for 2014-12-31 (Year 2014)
EE2014 = pd.DataFrame()
EE2014['Company_Code'] = dfs[0]['Company_Code'] 
EE2014['Date'] = '2014-12-31'
order = ['Date','Company_Code']
EE2014 = EE2014[order]

for n in range(len(filenames)):
  EE2014[dfnames[n]] = dfs[n][dfnames[n]+'14']

EE2014 = EE2014.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EE2014 = EE2014.reset_index()
EE2014.drop(['index'],axis=1,inplace=True)

# ESG_E_E Value for 2015-12-31 (Year 2015)
EE2015 = pd.DataFrame()
EE2015['Company_Code'] = dfs[0]['Company_Code'] 
EE2015['Date'] = '2015-12-31'
order = ['Date','Company_Code']
EE2015 = EE2015[order]

for n in range(len(filenames)):
  EE2015[dfnames[n]] = dfs[n][dfnames[n]+'15']

EE2015 = EE2015.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EE2015 = EE2015.reset_index()
EE2015.drop(['index'],axis=1,inplace=True)

# ESG_E_E Value for 2016-12-30 (Year 2016)
EE2016 = pd.DataFrame()
EE2016['Company_Code'] = dfs[0]['Company_Code'] 
EE2016['Date'] = '2016-12-30'
order = ['Date','Company_Code']
EE2016 = EE2016[order]

for n in range(len(filenames)):
  EE2016[dfnames[n]] = dfs[n][dfnames[n]+'16']

EE2016 = EE2016.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EE2016 = EE2016.reset_index()
EE2016.drop(['index'],axis=1,inplace=True)

# ESG_E_E Value for 2017-12-29 (Year 2017)
EE2017 = pd.DataFrame()
EE2017['Company_Code'] = dfs[0]['Company_Code'] 
EE2017['Date'] = '2017-12-29'
order = ['Date','Company_Code']
EE2017 = EE2017[order]

for n in range(len(filenames)):
  EE2017[dfnames[n]] = dfs[n][dfnames[n]+'17']

EE2017 = EE2017.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EE2017 = EE2017.reset_index()
EE2017.drop(['index'],axis=1,inplace=True)

# ESG_E_E Value for 2018-12-31 (Year 2018)
EE2018 = pd.DataFrame()
EE2018['Company_Code'] = dfs[0]['Company_Code'] 
EE2018['Date'] = '2018-12-31'
order = ['Date','Company_Code']
EE2018 = EE2018[order]

for n in range(len(filenames)):
  EE2018[dfnames[n]] = dfs[n][dfnames[n]+'18']

EE2018 = EE2018.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EE2018 = EE2018.reset_index()
EE2018.drop(['index'],axis=1,inplace=True)

# ESG_E_E Value for 2019-12-31 (Year 2019)
EE2019 = pd.DataFrame()
EE2019['Company_Code'] = dfs[0]['Company_Code'] 
EE2019['Date'] = '2019-12-31'
order = ['Date','Company_Code']
EE2019 = EE2019[order]

for n in range(len(filenames)):
  EE2019[dfnames[n]] = dfs[n][dfnames[n]+'19']

EE2019 = EE2019.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EE2019 = EE2019.reset_index()
EE2019.drop(['index'],axis=1,inplace=True)

# ESG_E_E Value for 2020-12-31 (Year 2020)
EE2020 = pd.DataFrame()
EE2020['Company_Code'] = dfs[0]['Company_Code'] 
EE2020['Date'] = '2020-12-31'
order = ['Date','Company_Code']
EE2020 = EE2020[order]

for n in range(len(filenames)):
  EE2020[dfnames[n]] = dfs[n][dfnames[n]+'20']

EE2020 = EE2020.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EE2020 = EE2020.reset_index()
EE2020.drop(['index'],axis=1,inplace=True)

ESG_E_E_Total = pd.concat([EE2011,EE2012,EE2013,EE2014,EE2015,EE2016,EE2017,EE2018,EE2019,EE2020])
ESG_E_E_Total = ESG_E_E_Total.reset_index()
ESG_E_E_Total.drop(['index'],axis=1,inplace=True)

# %% [markdown]
# ## For EI Data, Create ESG_E_I_Total

# %%
local_path = r'/content/drive/My Drive/ESG_Data/E_Innovation'
filenames = glob.glob(local_path + "/*.xlsx")

dfnames = list()

for i in range(len(filenames)):
  dfnames.append(os.path.basename(filenames[i]))
  dfnames[i] = dfnames[i][:-5]

dfs = [pd.read_excel(filename) for filename in filenames]
for m in range(len(filenames)):
  dfs[m].columns=['Company_Code','Company_Name',dfnames[m]+'11', dfnames[m]+'12', dfnames[m]+'13', dfnames[m]+'14', dfnames[m]+'15', dfnames[m]+'16', dfnames[m]+'17', dfnames[m]+'18', dfnames[m]+'19', dfnames[m]+'20']
  dfs[m].drop(dfs[m].head(2).index,inplace=True)
  dfs[m] = dfs[m].drop(columns=['Company_Name'])
  dfs[m] = dfs[m].reset_index()
  dfs[m].drop(['index'],axis=1,inplace=True)

# %%
# ESG_E_I Value for 2011-12-30 (Year 2011)
EI2011 = pd.DataFrame()
EI2011['Company_Code'] = dfs[0]['Company_Code'] 
EI2011['Date'] = '2011-12-30'
order = ['Date','Company_Code']
EI2011 = EI2011[order]

for n in range(len(filenames)):
  EI2011[dfnames[n]] = dfs[n][dfnames[n]+'11']

EI2011 = EI2011.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EI2011 = EI2011.reset_index()
EI2011.drop(['index'],axis=1,inplace=True)

# ESG_E_I Value for 2012-12-31 (Year 2012)
EI2012 = pd.DataFrame()
EI2012['Company_Code'] = dfs[0]['Company_Code'] 
EI2012['Date'] = '2012-12-31'
order = ['Date','Company_Code']
EI2012 = EI2012[order]

for n in range(len(filenames)):
  EI2012[dfnames[n]] = dfs[n][dfnames[n]+'12']

EI2012 = EI2012.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EI2012 = EI2012.reset_index()
EI2012.drop(['index'],axis=1,inplace=True)

# ESG_E_I Value for 2013-12-31 (Year 2013)
EI2013 = pd.DataFrame()
EI2013['Company_Code'] = dfs[0]['Company_Code'] 
EI2013['Date'] = '2013-12-31'
order = ['Date','Company_Code']
EI2013 = EI2013[order]

for n in range(len(filenames)):
  EI2013[dfnames[n]] = dfs[n][dfnames[n]+'13']

EI2013 = EI2013.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EI2013 = EI2013.reset_index()
EI2013.drop(['index'],axis=1,inplace=True)

# ESG_E_I Value for 2014-12-31 (Year 2014)
EI2014 = pd.DataFrame()
EI2014['Company_Code'] = dfs[0]['Company_Code'] 
EI2014['Date'] = '2014-12-31'
order = ['Date','Company_Code']
EI2014 = EI2014[order]

for n in range(len(filenames)):
  EI2014[dfnames[n]] = dfs[n][dfnames[n]+'14']

EI2014 = EI2014.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EI2014 = EI2014.reset_index()
EI2014.drop(['index'],axis=1,inplace=True)

# ESG_E_I Value for 2015-12-31 (Year 2015)
EI2015 = pd.DataFrame()
EI2015['Company_Code'] = dfs[0]['Company_Code'] 
EI2015['Date'] = '2015-12-31'
order = ['Date','Company_Code']
EI2015 = EI2015[order]

for n in range(len(filenames)):
  EI2015[dfnames[n]] = dfs[n][dfnames[n]+'15']

EI2015 = EI2015.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EI2015 = EI2015.reset_index()
EI2015.drop(['index'],axis=1,inplace=True)

# ESG_E_I Value for 2016-12-30 (Year 2016)
EI2016 = pd.DataFrame()
EI2016['Company_Code'] = dfs[0]['Company_Code'] 
EI2016['Date'] = '2016-12-30'
order = ['Date','Company_Code']
EI2016 = EI2016[order]

for n in range(len(filenames)):
  EI2016[dfnames[n]] = dfs[n][dfnames[n]+'16']

EI2016 = EI2016.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EI2016 = EI2016.reset_index()
EI2016.drop(['index'],axis=1,inplace=True)

# ESG_E_I Value for 2017-12-29 (Year 2017)
EI2017 = pd.DataFrame()
EI2017['Company_Code'] = dfs[0]['Company_Code'] 
EI2017['Date'] = '2017-12-29'
order = ['Date','Company_Code']
EI2017 = EI2017[order]

for n in range(len(filenames)):
  EI2017[dfnames[n]] = dfs[n][dfnames[n]+'17']

EI2017 = EI2017.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EI2017 = EI2017.reset_index()
EI2017.drop(['index'],axis=1,inplace=True)

# ESG_E_I Value for 2018-12-31 (Year 2018)
EI2018 = pd.DataFrame()
EI2018['Company_Code'] = dfs[0]['Company_Code'] 
EI2018['Date'] = '2018-12-31'
order = ['Date','Company_Code']
EI2018 = EI2018[order]

for n in range(len(filenames)):
  EI2018[dfnames[n]] = dfs[n][dfnames[n]+'18']

EI2018 = EI2018.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EI2018 = EI2018.reset_index()
EI2018.drop(['index'],axis=1,inplace=True)

# ESG_E_I Value for 2019-12-31 (Year 2019)
EI2019 = pd.DataFrame()
EI2019['Company_Code'] = dfs[0]['Company_Code'] 
EI2019['Date'] = '2019-12-31'
order = ['Date','Company_Code']
EI2019 = EI2019[order]

for n in range(len(filenames)):
  EI2019[dfnames[n]] = dfs[n][dfnames[n]+'19']

EI2019 = EI2019.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EI2019 = EI2019.reset_index()
EI2019.drop(['index'],axis=1,inplace=True)

# ESG_E_I Value for 2020-12-31 (Year 2020)
EI2020 = pd.DataFrame()
EI2020['Company_Code'] = dfs[0]['Company_Code'] 
EI2020['Date'] = '2020-12-31'
order = ['Date','Company_Code']
EI2020 = EI2020[order]

for n in range(len(filenames)):
  EI2020[dfnames[n]] = dfs[n][dfnames[n]+'20']

EI2020 = EI2020.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

EI2020 = EI2020.reset_index()
EI2020.drop(['index'],axis=1,inplace=True)

ESG_E_I_Total = pd.concat([EI2011,EI2012,EI2013,EI2014,EI2015,EI2016,EI2017,EI2018,EI2019,EI2020])
ESG_E_I_Total = ESG_E_I_Total.reset_index()
ESG_E_I_Total.drop(['index'],axis=1,inplace=True)
ESG_E_I_Total
# Out:
#             Date  ... E_I_Water_technologies
# 0     2011-12-30  ...                  False
# 1     2011-12-30  ...                  False
# 2     2011-12-30  ...                  False
# 3     2011-12-30  ...                  False
# 4     2011-12-30  ...                    NaN
# ...          ...  ...                    ...
# 4545  2020-12-31  ...                  False
# 4546  2020-12-31  ...                  False
# 4547  2020-12-31  ...                  False
# 4548  2020-12-31  ...                  False
# 4549  2020-12-31  ...                  False
#
# [4550 rows x 37 columns]

# %% [markdown]
# ## For ERU Data, Create ESG_E_RU_Total

# %%
local_path = r'/content/drive/My Drive/ESG_Data/E_Resource_Use'
filenames = glob.glob(local_path + "/*.xlsx")

dfnames = list()

for i in range(len(filenames)):
  dfnames.append(os.path.basename(filenames[i]))
  dfnames[i] = dfnames[i][:-5]

dfs = [pd.read_excel(filename) for filename in filenames]
for m in range(len(filenames)):
  dfs[m].columns=['Company_Code','Company_Name',dfnames[m]+'11', dfnames[m]+'12', dfnames[m]+'13', dfnames[m]+'14', dfnames[m]+'15', dfnames[m]+'16', dfnames[m]+'17', dfnames[m]+'18', dfnames[m]+'19', dfnames[m]+'20']
  dfs[m].drop(dfs[m].head(2).index,inplace=True)
  dfs[m] = dfs[m].drop(columns=['Company_Name'])
  dfs[m] = dfs[m].reset_index()
  dfs[m].drop(['index'],axis=1,inplace=True)

# %%
# ESG_E_RU Value for 2011-12-30 (Year 2011)
ERU2011 = pd.DataFrame()
ERU2011['Company_Code'] = dfs[0]['Company_Code'] 
ERU2011['Date'] = '2011-12-30'
order = ['Date','Company_Code']
ERU2011 = ERU2011[order]

for n in range(len(filenames)):
  ERU2011[dfnames[n]] = dfs[n][dfnames[n]+'11']

ERU2011 = ERU2011.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

ERU2011 = ERU2011.reset_index()
ERU2011.drop(['index'],axis=1,inplace=True)

# ESG_E_RU Value for 2012-12-31 (Year 2012)
ERU2012 = pd.DataFrame()
ERU2012['Company_Code'] = dfs[0]['Company_Code'] 
ERU2012['Date'] = '2012-12-31'
order = ['Date','Company_Code']
ERU2012 = ERU2012[order]

for n in range(len(filenames)):
  ERU2012[dfnames[n]] = dfs[n][dfnames[n]+'12']

ERU2012 = ERU2012.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

ERU2012 = ERU2012.reset_index()
ERU2012.drop(['index'],axis=1,inplace=True)

# ESG_E_RU Value for 2013-12-31 (Year 2013)
ERU2013 = pd.DataFrame()
ERU2013['Company_Code'] = dfs[0]['Company_Code'] 
ERU2013['Date'] = '2013-12-31'
order = ['Date','Company_Code']
ERU2013 = ERU2013[order]

for n in range(len(filenames)):
  ERU2013[dfnames[n]] = dfs[n][dfnames[n]+'13']

ERU2013 = ERU2013.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

ERU2013 = ERU2013.reset_index()
ERU2013.drop(['index'],axis=1,inplace=True)

# ESG_E_RU Value for 2014-12-31 (Year 2014)
ERU2014 = pd.DataFrame()
ERU2014['Company_Code'] = dfs[0]['Company_Code'] 
ERU2014['Date'] = '2014-12-31'
order = ['Date','Company_Code']
ERU2014 = ERU2014[order]

for n in range(len(filenames)):
  ERU2014[dfnames[n]] = dfs[n][dfnames[n]+'14']

ERU2014 = ERU2014.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

ERU2014 = ERU2014.reset_index()
ERU2014.drop(['index'],axis=1,inplace=True)

# ESG_E_RU Value for 2015-12-31 (Year 2015)
ERU2015 = pd.DataFrame()
ERU2015['Company_Code'] = dfs[0]['Company_Code'] 
ERU2015['Date'] = '2015-12-31'
order = ['Date','Company_Code']
ERU2015 = ERU2015[order]

for n in range(len(filenames)):
  ERU2015[dfnames[n]] = dfs[n][dfnames[n]+'15']

ERU2015 = ERU2015.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

ERU2015 = ERU2015.reset_index()
ERU2015.drop(['index'],axis=1,inplace=True)

# ESG_E_RU Value for 2016-12-30 (Year 2016)
ERU2016 = pd.DataFrame()
ERU2016['Company_Code'] = dfs[0]['Company_Code'] 
ERU2016['Date'] = '2016-12-30'
order = ['Date','Company_Code']
ERU2016 = ERU2016[order]

for n in range(len(filenames)):
  ERU2016[dfnames[n]] = dfs[n][dfnames[n]+'16']

ERU2016 = ERU2016.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

ERU2016 = ERU2016.reset_index()
ERU2016.drop(['index'],axis=1,inplace=True)

# ESG_E_RU Value for 2017-12-29 (Year 2017)
ERU2017 = pd.DataFrame()
ERU2017['Company_Code'] = dfs[0]['Company_Code'] 
ERU2017['Date'] = '2017-12-29'
order = ['Date','Company_Code']
ERU2017 = ERU2017[order]

for n in range(len(filenames)):
  ERU2017[dfnames[n]] = dfs[n][dfnames[n]+'17']

ERU2017 = ERU2017.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

ERU2017 = ERU2017.reset_index()
ERU2017.drop(['index'],axis=1,inplace=True)

# ESG_E_RU Value for 2018-12-31 (Year 2018)
ERU2018 = pd.DataFrame()
ERU2018['Company_Code'] = dfs[0]['Company_Code'] 
ERU2018['Date'] = '2018-12-31'
order = ['Date','Company_Code']
ERU2018 = ERU2018[order]

for n in range(len(filenames)):
  ERU2018[dfnames[n]] = dfs[n][dfnames[n]+'18']

ERU2018 = ERU2018.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

ERU2018 = ERU2018.reset_index()
ERU2018.drop(['index'],axis=1,inplace=True)

# ESG_E_RU Value for 2019-12-31 (Year 2019)
ERU2019 = pd.DataFrame()
ERU2019['Company_Code'] = dfs[0]['Company_Code'] 
ERU2019['Date'] = '2019-12-31'
order = ['Date','Company_Code']
ERU2019 = ERU2019[order]

for n in range(len(filenames)):
  ERU2019[dfnames[n]] = dfs[n][dfnames[n]+'19']

ERU2019 = ERU2019.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

ERU2019 = ERU2019.reset_index()
ERU2019.drop(['index'],axis=1,inplace=True)

# ESG_E_RU Value for 2020-12-31 (Year 2020)
ERU2020 = pd.DataFrame()
ERU2020['Company_Code'] = dfs[0]['Company_Code'] 
ERU2020['Date'] = '2020-12-31'
order = ['Date','Company_Code']
ERU2020 = ERU2020[order]

for n in range(len(filenames)):
  ERU2020[dfnames[n]] = dfs[n][dfnames[n]+'20']

ERU2020 = ERU2020.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

ERU2020 = ERU2020.reset_index()
ERU2020.drop(['index'],axis=1,inplace=True)

ESG_E_RU_Total = pd.concat([ERU2011,ERU2012,ERU2013,ERU2014,ERU2015,ERU2016,ERU2017,ERU2018,ERU2019,ERU2020])
ESG_E_RU_Total = ESG_E_RU_Total.reset_index()
ESG_E_RU_Total.drop(['index'],axis=1,inplace=True)
ESG_E_RU_Total
# Out:
#             Date  ... E_RU_Water_Withdrawal_Total
# 0     2011-12-30  ...                      921000
# 1     2011-12-30  ...                         NaN
# 2     2011-12-30  ...                      800651
# 3     2011-12-30  ...                         NaN
# 4     2011-12-30  ...                         NaN
# ...          ...  ...                         ...
# 4545  2020-12-31  ...                         NaN
# 4546  2020-12-31  ...                     2175450
# 4547  2020-12-31  ...                         NaN
# 4548  2020-12-31  ...                         NaN
# 4549  2020-12-31  ...                         NaN
#
# [4550 rows x 43 columns]

# %% [markdown]
# ## For GC Data, Create ESG_G_C_Total

# %%
local_path = r'/content/drive/My Drive/ESG_Data/G_CSR_Strategy'
filenames = glob.glob(local_path + "/*.xlsx")

dfnames = list()

for i in range(len(filenames)):
  dfnames.append(os.path.basename(filenames[i]))
  dfnames[i] = dfnames[i][:-5]

dfs = [pd.read_excel(filename) for filename in filenames]
for m in range(len(filenames)):
  dfs[m].columns=['Company_Code','Company_Name',dfnames[m]+'11', dfnames[m]+'12', dfnames[m]+'13', dfnames[m]+'14', dfnames[m]+'15', dfnames[m]+'16', dfnames[m]+'17', dfnames[m]+'18', dfnames[m]+'19', dfnames[m]+'20']
  dfs[m].drop(dfs[m].head(2).index,inplace=True)
  dfs[m] = dfs[m].drop(columns=['Company_Name'])
  dfs[m] = dfs[m].reset_index()
  dfs[m].drop(['index'],axis=1,inplace=True)

# %%
# ESG_GC Value for 2011-12-30 (Year 2011)
GC2011 = pd.DataFrame()
GC2011['Company_Code'] = dfs[0]['Company_Code'] 
GC2011['Date'] = '2011-12-30'
order = ['Date','Company_Code']
GC2011 = GC2011[order]

for n in range(len(filenames)):
  GC2011[dfnames[n]] = dfs[n][dfnames[n]+'11']

GC2011 = GC2011.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GC2011 = GC2011.reset_index()
GC2011.drop(['index'],axis=1,inplace=True)

# ESG_GC Value for 2012-12-31 (Year 2012)
GC2012 = pd.DataFrame()
GC2012['Company_Code'] = dfs[0]['Company_Code'] 
GC2012['Date'] = '2012-12-31'
order = ['Date','Company_Code']
GC2012 = GC2012[order]

for n in range(len(filenames)):
  GC2012[dfnames[n]] = dfs[n][dfnames[n]+'12']

GC2012 = GC2012.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GC2012 = GC2012.reset_index()
GC2012.drop(['index'],axis=1,inplace=True)

# ESG_GC Value for 2013-12-31 (Year 2013)
GC2013 = pd.DataFrame()
GC2013['Company_Code'] = dfs[0]['Company_Code'] 
GC2013['Date'] = '2013-12-31'
order = ['Date','Company_Code']
GC2013 = GC2013[order]

for n in range(len(filenames)):
  GC2013[dfnames[n]] = dfs[n][dfnames[n]+'13']

GC2013 = GC2013.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GC2013 = GC2013.reset_index()
GC2013.drop(['index'],axis=1,inplace=True)

# ESG_GC Value for 2014-12-31 (Year 2014)
GC2014 = pd.DataFrame()
GC2014['Company_Code'] = dfs[0]['Company_Code'] 
GC2014['Date'] = '2014-12-31'
order = ['Date','Company_Code']
GC2014 = GC2014[order]

for n in range(len(filenames)):
  GC2014[dfnames[n]] = dfs[n][dfnames[n]+'14']

GC2014 = GC2014.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GC2014 = GC2014.reset_index()
GC2014.drop(['index'],axis=1,inplace=True)

# ESG_GC Value for 2015-12-31 (Year 2015)
GC2015 = pd.DataFrame()
GC2015['Company_Code'] = dfs[0]['Company_Code'] 
GC2015['Date'] = '2015-12-31'
order = ['Date','Company_Code']
GC2015 = GC2015[order]

for n in range(len(filenames)):
  GC2015[dfnames[n]] = dfs[n][dfnames[n]+'15']

GC2015 = GC2015.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GC2015 = GC2015.reset_index()
GC2015.drop(['index'],axis=1,inplace=True)

# ESG_GC Value for 2016-12-30 (Year 2016)
GC2016 = pd.DataFrame()
GC2016['Company_Code'] = dfs[0]['Company_Code'] 
GC2016['Date'] = '2016-12-30'
order = ['Date','Company_Code']
GC2016 = GC2016[order]

for n in range(len(filenames)):
  GC2016[dfnames[n]] = dfs[n][dfnames[n]+'16']

GC2016 = GC2016.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GC2016 = GC2016.reset_index()
GC2016.drop(['index'],axis=1,inplace=True)

# ESG_GC Value for 2017-12-29 (Year 2017)
GC2017 = pd.DataFrame()
GC2017['Company_Code'] = dfs[0]['Company_Code'] 
GC2017['Date'] = '2017-12-29'
order = ['Date','Company_Code']
GC2017 = GC2017[order]

for n in range(len(filenames)):
  GC2017[dfnames[n]] = dfs[n][dfnames[n]+'17']

GC2017 = GC2017.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GC2017 = GC2017.reset_index()
GC2017.drop(['index'],axis=1,inplace=True)

# ESG_GC Value for 2018-12-31 (Year 2018)
GC2018 = pd.DataFrame()
GC2018['Company_Code'] = dfs[0]['Company_Code'] 
GC2018['Date'] = '2018-12-31'
order = ['Date','Company_Code']
GC2018 = GC2018[order]

for n in range(len(filenames)):
  GC2018[dfnames[n]] = dfs[n][dfnames[n]+'18']

GC2018 = GC2018.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GC2018 = GC2018.reset_index()
GC2018.drop(['index'],axis=1,inplace=True)

# ESG_GC Value for 2019-12-31 (Year 2019)
GC2019 = pd.DataFrame()
GC2019['Company_Code'] = dfs[0]['Company_Code'] 
GC2019['Date'] = '2019-12-31'
order = ['Date','Company_Code']
GC2019 = GC2019[order]

for n in range(len(filenames)):
  GC2019[dfnames[n]] = dfs[n][dfnames[n]+'19']

GC2019 = GC2019.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GC2019 = GC2019.reset_index()
GC2019.drop(['index'],axis=1,inplace=True)

# ESG_GC Value for 2020-12-31 (Year 2020)
GC2020 = pd.DataFrame()
GC2020['Company_Code'] = dfs[0]['Company_Code'] 
GC2020['Date'] = '2020-12-31'
order = ['Date','Company_Code']
GC2020 = GC2020[order]

for n in range(len(filenames)):
  GC2020[dfnames[n]] = dfs[n][dfnames[n]+'20']

GC2020 = GC2020.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GC2020 = GC2020.reset_index()
GC2020.drop(['index'],axis=1,inplace=True)

ESG_G_C_Total = pd.concat([GC2011,GC2012,GC2013,GC2014,GC2015,GC2016,GC2017,GC2018,GC2019,GC2020])
ESG_G_C_Total = ESG_G_C_Total.reset_index()
ESG_G_C_Total.drop(['index'],axis=1,inplace=True)
ESG_G_C_Total
# Out:
#             Date Company_Code  ... G_C_Stakeholder_Engagement G_C_UNPRI_Signatory
# 0     2011-12-30          A.N  ...                       True               False
# 1     2011-12-30        AAP.N  ...                      False               False
# 2     2011-12-30      AAPL.OQ  ...                      False               False
# 3     2011-12-30        ABC.N  ...                      False               False
# 4     2011-12-30      ABMD.OQ  ...                        NaN                 NaN
# ...          ...          ...  ...                        ...                 ...
# 4545  2020-12-31      XRAY.OQ  ...                      False               False
# 4546  2020-12-31        YUM.N  ...                       True               False
# 4547  2020-12-31        ZBH.N  ...                      False               False
# 4548  2020-12-31      ZBRA.OQ  ...                      False               False
# ...

# %% [markdown]
# ## For GM Data, Create ESG_G_M_Total

# %%
local_path = r'/content/drive/My Drive/ESG_Data/G_Management'
filenames = glob.glob(local_path + "/*.xlsx")

dfnames = list()

for i in range(len(filenames)):
  dfnames.append(os.path.basename(filenames[i]))
  dfnames[i] = dfnames[i][:-5]

dfs = [pd.read_excel(filename) for filename in filenames]
for m in range(len(filenames)):
  dfs[m].columns=['Company_Code','Company_Name',dfnames[m]+'11', dfnames[m]+'12', dfnames[m]+'13', dfnames[m]+'14', dfnames[m]+'15', dfnames[m]+'16', dfnames[m]+'17', dfnames[m]+'18', dfnames[m]+'19', dfnames[m]+'20']
  dfs[m].drop(dfs[m].head(2).index,inplace=True)
  dfs[m] = dfs[m].drop(columns=['Company_Name'])
  dfs[m] = dfs[m].reset_index()
  dfs[m].drop(['index'],axis=1,inplace=True)

# %%
# ESG_GM Value for 2011-12-30 (Year 2011)
GM2011 = pd.DataFrame()
GM2011['Company_Code'] = dfs[0]['Company_Code'] 
GM2011['Date'] = '2011-12-30'
order = ['Date','Company_Code']
GM2011 = GM2011[order]

for n in range(len(filenames)):
  GM2011[dfnames[n]] = dfs[n][dfnames[n]+'11']

GM2011 = GM2011.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GM2011 = GM2011.reset_index()
GM2011.drop(['index'],axis=1,inplace=True)

# ESG_GM Value for 2012-12-31 (Year 2012)
GM2012 = pd.DataFrame()
GM2012['Company_Code'] = dfs[0]['Company_Code'] 
GM2012['Date'] = '2012-12-31'
order = ['Date','Company_Code']
GM2012 = GM2012[order]

for n in range(len(filenames)):
  GM2012[dfnames[n]] = dfs[n][dfnames[n]+'12']

GM2012 = GM2012.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GM2012 = GM2012.reset_index()
GM2012.drop(['index'],axis=1,inplace=True)

# ESG_GM Value for 2013-12-31 (Year 2013)
GM2013 = pd.DataFrame()
GM2013['Company_Code'] = dfs[0]['Company_Code'] 
GM2013['Date'] = '2013-12-31'
order = ['Date','Company_Code']
GM2013 = GM2013[order]

for n in range(len(filenames)):
  GM2013[dfnames[n]] = dfs[n][dfnames[n]+'13']

GM2013 = GM2013.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GM2013 = GM2013.reset_index()
GM2013.drop(['index'],axis=1,inplace=True)

# ESG_GM Value for 2014-12-31 (Year 2014)
GM2014 = pd.DataFrame()
GM2014['Company_Code'] = dfs[0]['Company_Code'] 
GM2014['Date'] = '2014-12-31'
order = ['Date','Company_Code']
GM2014 = GM2014[order]

for n in range(len(filenames)):
  GM2014[dfnames[n]] = dfs[n][dfnames[n]+'14']

GM2014 = GM2014.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GM2014 = GM2014.reset_index()
GM2014.drop(['index'],axis=1,inplace=True)

# ESG_GM Value for 2015-12-31 (Year 2015)
GM2015 = pd.DataFrame()
GM2015['Company_Code'] = dfs[0]['Company_Code'] 
GM2015['Date'] = '2015-12-31'
order = ['Date','Company_Code']
GM2015 = GM2015[order]

for n in range(len(filenames)):
  GM2015[dfnames[n]] = dfs[n][dfnames[n]+'15']

GM2015 = GM2015.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GM2015 = GM2015.reset_index()
GM2015.drop(['index'],axis=1,inplace=True)

# ESG_GM Value for 2016-12-30 (Year 2016)
GM2016 = pd.DataFrame()
GM2016['Company_Code'] = dfs[0]['Company_Code'] 
GM2016['Date'] = '2016-12-30'
order = ['Date','Company_Code']
GM2016 = GM2016[order]

for n in range(len(filenames)):
  GM2016[dfnames[n]] = dfs[n][dfnames[n]+'16']

GM2016 = GM2016.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GM2016 = GM2016.reset_index()
GM2016.drop(['index'],axis=1,inplace=True)

# ESG_GM Value for 2017-12-29 (Year 2017)
GM2017 = pd.DataFrame()
GM2017['Company_Code'] = dfs[0]['Company_Code'] 
GM2017['Date'] = '2017-12-29'
order = ['Date','Company_Code']
GM2017 = GM2017[order]

for n in range(len(filenames)):
  GM2017[dfnames[n]] = dfs[n][dfnames[n]+'17']

GM2017 = GM2017.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GM2017 = GM2017.reset_index()
GM2017.drop(['index'],axis=1,inplace=True)

# ESG_GM Value for 2018-12-31 (Year 2018)
GM2018 = pd.DataFrame()
GM2018['Company_Code'] = dfs[0]['Company_Code'] 
GM2018['Date'] = '2018-12-31'
order = ['Date','Company_Code']
GM2018 = GM2018[order]

for n in range(len(filenames)):
  GM2018[dfnames[n]] = dfs[n][dfnames[n]+'18']

GM2018 = GM2018.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GM2018 = GM2018.reset_index()
GM2018.drop(['index'],axis=1,inplace=True)

# ESG_GM Value for 2019-12-31 (Year 2019)
GM2019 = pd.DataFrame()
GM2019['Company_Code'] = dfs[0]['Company_Code'] 
GM2019['Date'] = '2019-12-31'
order = ['Date','Company_Code']
GM2019 = GM2019[order]

for n in range(len(filenames)):
  GM2019[dfnames[n]] = dfs[n][dfnames[n]+'19']

GM2019 = GM2019.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GM2019 = GM2019.reset_index()
GM2019.drop(['index'],axis=1,inplace=True)

# ESG_GM Value for 2020-12-31 (Year 2020)
GM2020 = pd.DataFrame()
GM2020['Company_Code'] = dfs[0]['Company_Code'] 
GM2020['Date'] = '2020-12-31'
order = ['Date','Company_Code']
GM2020 = GM2020[order]

for n in range(len(filenames)):
  GM2020[dfnames[n]] = dfs[n][dfnames[n]+'20']

GM2020 = GM2020.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GM2020 = GM2020.reset_index()
GM2020.drop(['index'],axis=1,inplace=True)

ESG_G_M_Total = pd.concat([GM2011,GM2012,GM2013,GM2014,GM2015,GM2016,GM2017,GM2018,GM2019,GM2020])
ESG_G_M_Total = ESG_G_M_Total.reset_index()
ESG_G_M_Total.drop(['index'],axis=1,inplace=True)
ESG_G_M_Total
# Out:
#             Date  ... G_M_Policy_Executive_Compensation_Performance
# 0     2011-12-30  ...                                          True
# 1     2011-12-30  ...                                          True
# 2     2011-12-30  ...                                          True
# 3     2011-12-30  ...                                          True
# 4     2011-12-30  ...                                           NaN
# ...          ...  ...                                           ...
# 4545  2020-12-31  ...                                          True
# 4546  2020-12-31  ...                                          True
# 4547  2020-12-31  ...                                          True
# 4548  2020-12-31  ...                                          True
# 4549  2020-12-31  ...                                          True
#
# [4550 rows x 75 columns]

# %% [markdown]
# ## For GS Data, Create ESG_G_S_Total

# %%
local_path = r'/content/drive/My Drive/ESG_Data/G_Shareholders'
filenames = glob.glob(local_path + "/*.xlsx")

dfnames = list()

for i in range(len(filenames)):
  dfnames.append(os.path.basename(filenames[i]))
  dfnames[i] = dfnames[i][:-5]

dfs = [pd.read_excel(filename) for filename in filenames]
for m in range(len(filenames)):
  dfs[m].columns=['Company_Code','Company_Name',dfnames[m]+'11', dfnames[m]+'12', dfnames[m]+'13', dfnames[m]+'14', dfnames[m]+'15', dfnames[m]+'16', dfnames[m]+'17', dfnames[m]+'18', dfnames[m]+'19', dfnames[m]+'20']
  dfs[m].drop(dfs[m].head(2).index,inplace=True)
  dfs[m] = dfs[m].drop(columns=['Company_Name'])
  dfs[m] = dfs[m].reset_index()
  dfs[m].drop(['index'],axis=1,inplace=True)

# %%
# ESG_GS Value for 2011-12-30 (Year 2011)
GS2011 = pd.DataFrame()
GS2011['Company_Code'] = dfs[0]['Company_Code'] 
GS2011['Date'] = '2011-12-30'
order = ['Date','Company_Code']
GS2011 = GS2011[order]

for n in range(len(filenames)):
  GS2011[dfnames[n]] = dfs[n][dfnames[n]+'11']

GS2011 = GS2011.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GS2011 = GS2011.reset_index()
GS2011.drop(['index'],axis=1,inplace=True)

# ESG_GS Value for 2012-12-31 (Year 2012)
GS2012 = pd.DataFrame()
GS2012['Company_Code'] = dfs[0]['Company_Code'] 
GS2012['Date'] = '2012-12-31'
order = ['Date','Company_Code']
GS2012 = GS2012[order]

for n in range(len(filenames)):
  GS2012[dfnames[n]] = dfs[n][dfnames[n]+'12']

GS2012 = GS2012.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GS2012 = GS2012.reset_index()
GS2012.drop(['index'],axis=1,inplace=True)

# ESG_GS Value for 2013-12-31 (Year 2013)
GS2013 = pd.DataFrame()
GS2013['Company_Code'] = dfs[0]['Company_Code'] 
GS2013['Date'] = '2013-12-31'
order = ['Date','Company_Code']
GS2013 = GS2013[order]

for n in range(len(filenames)):
  GS2013[dfnames[n]] = dfs[n][dfnames[n]+'13']

GS2013 = GS2013.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GS2013 = GS2013.reset_index()
GS2013.drop(['index'],axis=1,inplace=True)

# ESG_GS Value for 2014-12-31 (Year 2014)
GS2014 = pd.DataFrame()
GS2014['Company_Code'] = dfs[0]['Company_Code'] 
GS2014['Date'] = '2014-12-31'
order = ['Date','Company_Code']
GS2014 = GS2014[order]

for n in range(len(filenames)):
  GS2014[dfnames[n]] = dfs[n][dfnames[n]+'14']

GS2014 = GS2014.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GS2014 = GS2014.reset_index()
GS2014.drop(['index'],axis=1,inplace=True)

# ESG_GS Value for 2015-12-31 (Year 2015)
GS2015 = pd.DataFrame()
GS2015['Company_Code'] = dfs[0]['Company_Code'] 
GS2015['Date'] = '2015-12-31'
order = ['Date','Company_Code']
GS2015 = GS2015[order]

for n in range(len(filenames)):
  GS2015[dfnames[n]] = dfs[n][dfnames[n]+'15']

GS2015 = GS2015.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GS2015 = GS2015.reset_index()
GS2015.drop(['index'],axis=1,inplace=True)

# ESG_GS Value for 2016-12-30 (Year 2016)
GS2016 = pd.DataFrame()
GS2016['Company_Code'] = dfs[0]['Company_Code'] 
GS2016['Date'] = '2016-12-30'
order = ['Date','Company_Code']
GS2016 = GS2016[order]

for n in range(len(filenames)):
  GS2016[dfnames[n]] = dfs[n][dfnames[n]+'16']

GS2016 = GS2016.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GS2016 = GS2016.reset_index()
GS2016.drop(['index'],axis=1,inplace=True)

# ESG_GS Value for 2017-12-29 (Year 2017)
GS2017 = pd.DataFrame()
GS2017['Company_Code'] = dfs[0]['Company_Code'] 
GS2017['Date'] = '2017-12-29'
order = ['Date','Company_Code']
GS2017 = GS2017[order]

for n in range(len(filenames)):
  GS2017[dfnames[n]] = dfs[n][dfnames[n]+'17']

GS2017 = GS2017.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GS2017 = GS2017.reset_index()
GS2017.drop(['index'],axis=1,inplace=True)

# ESG_GS Value for 2018-12-31 (Year 2018)
GS2018 = pd.DataFrame()
GS2018['Company_Code'] = dfs[0]['Company_Code'] 
GS2018['Date'] = '2018-12-31'
order = ['Date','Company_Code']
GS2018 = GS2018[order]

for n in range(len(filenames)):
  GS2018[dfnames[n]] = dfs[n][dfnames[n]+'18']

GS2018 = GS2018.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GS2018 = GS2018.reset_index()
GS2018.drop(['index'],axis=1,inplace=True)

# ESG_GS Value for 2019-12-31 (Year 2019)
GS2019 = pd.DataFrame()
GS2019['Company_Code'] = dfs[0]['Company_Code'] 
GS2019['Date'] = '2019-12-31'
order = ['Date','Company_Code']
GS2019 = GS2019[order]

for n in range(len(filenames)):
  GS2019[dfnames[n]] = dfs[n][dfnames[n]+'19']

GS2019 = GS2019.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GS2019 = GS2019.reset_index()
GS2019.drop(['index'],axis=1,inplace=True)

# ESG_GS Value for 2020-12-31 (Year 2020)
GS2020 = pd.DataFrame()
GS2020['Company_Code'] = dfs[0]['Company_Code'] 
GS2020['Date'] = '2020-12-31'
order = ['Date','Company_Code']
GS2020 = GS2020[order]

for n in range(len(filenames)):
  GS2020[dfnames[n]] = dfs[n][dfnames[n]+'20']

GS2020 = GS2020.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

GS2020 = GS2020.reset_index()
GS2020.drop(['index'],axis=1,inplace=True)

ESG_G_S_Total = pd.concat([GS2011,GS2012,GS2013,GS2014,GS2015,GS2016,GS2017,GS2018,GS2019,GS2020])
ESG_G_S_Total = ESG_G_S_Total.reset_index()
ESG_G_S_Total.drop(['index'],axis=1,inplace=True)
ESG_G_S_Total
# Out:
#             Date Company_Code  ... G_S_Voting_Cap G_S_Written_Consent_Requirements
# 0     2011-12-30          A.N  ...          False                            False
# 1     2011-12-30        AAP.N  ...          False                            False
# 2     2011-12-30      AAPL.OQ  ...          False                             True
# 3     2011-12-30        ABC.N  ...          False                            False
# 4     2011-12-30      ABMD.OQ  ...            NaN                              NaN
# ...          ...          ...  ...            ...                              ...
# 4545  2020-12-31      XRAY.OQ  ...          False                            False
# 4546  2020-12-31        YUM.N  ...          False                              NaN
# 4547  2020-12-31        ZBH.N  ...          False                            False
# 4548  2020-12-31      ZBRA.OQ  ...          False                             True
# ...

# %% [markdown]
# ## For SC Data, Create ESG_S_C_Total

# %%
local_path = r'/content/drive/My Drive/ESG_Data/S_Community'
filenames = glob.glob(local_path + "/*.xlsx")

dfnames = list()

for i in range(len(filenames)):
  dfnames.append(os.path.basename(filenames[i]))
  dfnames[i] = dfnames[i][:-5]

dfs = [pd.read_excel(filename) for filename in filenames]
for m in range(len(filenames)):
  dfs[m].columns=['Company_Code','Company_Name',dfnames[m]+'11', dfnames[m]+'12', dfnames[m]+'13', dfnames[m]+'14', dfnames[m]+'15', dfnames[m]+'16', dfnames[m]+'17', dfnames[m]+'18', dfnames[m]+'19', dfnames[m]+'20']
  dfs[m].drop(dfs[m].head(2).index,inplace=True)
  dfs[m] = dfs[m].drop(columns=['Company_Name'])
  dfs[m] = dfs[m].reset_index()
  dfs[m].drop(['index'],axis=1,inplace=True)

# %%
# ESG_SC Value for 2011-12-30 (Year 2011)
SC2011 = pd.DataFrame()
SC2011['Company_Code'] = dfs[0]['Company_Code'] 
SC2011['Date'] = '2011-12-30'
order = ['Date','Company_Code']
SC2011 = SC2011[order]

for n in range(len(filenames)):
  SC2011[dfnames[n]] = dfs[n][dfnames[n]+'11']

SC2011 = SC2011.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SC2011 = SC2011.reset_index()
SC2011.drop(['index'],axis=1,inplace=True)

# ESG_SC Value for 2012-12-31 (Year 2012)
SC2012 = pd.DataFrame()
SC2012['Company_Code'] = dfs[0]['Company_Code'] 
SC2012['Date'] = '2012-12-31'
order = ['Date','Company_Code']
SC2012 = SC2012[order]

for n in range(len(filenames)):
  SC2012[dfnames[n]] = dfs[n][dfnames[n]+'12']

SC2012 = SC2012.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SC2012 = SC2012.reset_index()
SC2012.drop(['index'],axis=1,inplace=True)

# ESG_SC Value for 2013-12-31 (Year 2013)
SC2013 = pd.DataFrame()
SC2013['Company_Code'] = dfs[0]['Company_Code'] 
SC2013['Date'] = '2013-12-31'
order = ['Date','Company_Code']
SC2013 = SC2013[order]

for n in range(len(filenames)):
  SC2013[dfnames[n]] = dfs[n][dfnames[n]+'13']

SC2013 = SC2013.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SC2013 = SC2013.reset_index()
SC2013.drop(['index'],axis=1,inplace=True)

# ESG_SC Value for 2014-12-31 (Year 2014)
SC2014 = pd.DataFrame()
SC2014['Company_Code'] = dfs[0]['Company_Code'] 
SC2014['Date'] = '2014-12-31'
order = ['Date','Company_Code']
SC2014 = SC2014[order]

for n in range(len(filenames)):
  SC2014[dfnames[n]] = dfs[n][dfnames[n]+'14']

SC2014 = SC2014.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SC2014 = SC2014.reset_index()
SC2014.drop(['index'],axis=1,inplace=True)

# ESG_SC Value for 2015-12-31 (Year 2015)
SC2015 = pd.DataFrame()
SC2015['Company_Code'] = dfs[0]['Company_Code'] 
SC2015['Date'] = '2015-12-31'
order = ['Date','Company_Code']
SC2015 = SC2015[order]

for n in range(len(filenames)):
  SC2015[dfnames[n]] = dfs[n][dfnames[n]+'15']

SC2015 = SC2015.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SC2015 = SC2015.reset_index()
SC2015.drop(['index'],axis=1,inplace=True)

# ESG_SC Value for 2016-12-30 (Year 2016)
SC2016 = pd.DataFrame()
SC2016['Company_Code'] = dfs[0]['Company_Code'] 
SC2016['Date'] = '2016-12-30'
order = ['Date','Company_Code']
SC2016 = SC2016[order]

for n in range(len(filenames)):
  SC2016[dfnames[n]] = dfs[n][dfnames[n]+'16']

SC2016 = SC2016.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SC2016 = SC2016.reset_index()
SC2016.drop(['index'],axis=1,inplace=True)

# ESG_SC Value for 2017-12-29 (Year 2017)
SC2017 = pd.DataFrame()
SC2017['Company_Code'] = dfs[0]['Company_Code'] 
SC2017['Date'] = '2017-12-29'
order = ['Date','Company_Code']
SC2017 = SC2017[order]

for n in range(len(filenames)):
  SC2017[dfnames[n]] = dfs[n][dfnames[n]+'17']

SC2017 = SC2017.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SC2017 = SC2017.reset_index()
SC2017.drop(['index'],axis=1,inplace=True)

# ESG_SC Value for 2018-12-31 (Year 2018)
SC2018 = pd.DataFrame()
SC2018['Company_Code'] = dfs[0]['Company_Code'] 
SC2018['Date'] = '2018-12-31'
order = ['Date','Company_Code']
SC2018 = SC2018[order]

for n in range(len(filenames)):
  SC2018[dfnames[n]] = dfs[n][dfnames[n]+'18']

SC2018 = SC2018.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SC2018 = SC2018.reset_index()
SC2018.drop(['index'],axis=1,inplace=True)

# ESG_SC Value for 2019-12-31 (Year 2019)
SC2019 = pd.DataFrame()
SC2019['Company_Code'] = dfs[0]['Company_Code'] 
SC2019['Date'] = '2019-12-31'
order = ['Date','Company_Code']
SC2019 = SC2019[order]

for n in range(len(filenames)):
  SC2019[dfnames[n]] = dfs[n][dfnames[n]+'19']

SC2019 = SC2019.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SC2019 = SC2019.reset_index()
SC2019.drop(['index'],axis=1,inplace=True)

# ESG_SC Value for 2020-12-31 (Year 2020)
SC2020 = pd.DataFrame()
SC2020['Company_Code'] = dfs[0]['Company_Code'] 
SC2020['Date'] = '2020-12-31'
order = ['Date','Company_Code']
SC2020 = SC2020[order]

for n in range(len(filenames)):
  SC2020[dfnames[n]] = dfs[n][dfnames[n]+'20']

SC2020 = SC2020.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SC2020 = SC2020.reset_index()
SC2020.drop(['index'],axis=1,inplace=True)

ESG_S_C_Total = pd.concat([SC2011,SC2012,SC2013,SC2014,SC2015,SC2016,SC2017,SC2018,SC2019,SC2020])
ESG_S_C_Total = ESG_S_C_Total.reset_index()
ESG_S_C_Total.drop(['index'],axis=1,inplace=True)
ESG_S_C_Total
# Out:
#             Date  ... S_C_Whistleblower_Protection
# 0     2011-12-30  ...                          NaN
# 1     2011-12-30  ...                          NaN
# 2     2011-12-30  ...                          NaN
# 3     2011-12-30  ...                          NaN
# 4     2011-12-30  ...                          NaN
# ...          ...  ...                          ...
# 4545  2020-12-31  ...                          NaN
# 4546  2020-12-31  ...                          NaN
# 4547  2020-12-31  ...                          NaN
# 4548  2020-12-31  ...                          NaN
# 4549  2020-12-31  ...                          NaN
#
# [4550 rows x 34 columns]

# %% [markdown]
# ## For SP Data, Create ESG_S_P_Total

# %%
local_path = r'/content/drive/My Drive/ESG_Data/S_Product_Responsibility'
filenames = glob.glob(local_path + "/*.xlsx")

dfnames = list()

for i in range(len(filenames)):
  dfnames.append(os.path.basename(filenames[i]))
  dfnames[i] = dfnames[i][:-5]

dfs = [pd.read_excel(filename) for filename in filenames]
for m in range(len(filenames)):
  #print(dfs[m].columns)
  dfs[m].columns=['Company_Code','Company_Name',dfnames[m]+'11', dfnames[m]+'12', dfnames[m]+'13', dfnames[m]+'14', dfnames[m]+'15', dfnames[m]+'16', dfnames[m]+'17', dfnames[m]+'18', dfnames[m]+'19', dfnames[m]+'20']
  dfs[m].drop(dfs[m].head(2).index,inplace=True)
  dfs[m] = dfs[m].drop(columns=['Company_Name'])
  dfs[m] = dfs[m].reset_index()
  dfs[m].drop(['index'],axis=1,inplace=True)

# %%
# ESG_SP Value for 2011-12-30 (Year 2011)
SP2011 = pd.DataFrame()
SP2011['Company_Code'] = dfs[0]['Company_Code'] 
SP2011['Date'] = '2011-12-30'
order = ['Date','Company_Code']
SP2011 = SP2011[order]

for n in range(len(filenames)):
  SP2011[dfnames[n]] = dfs[n][dfnames[n]+'11']

SP2011 = SP2011.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SP2011 = SP2011.reset_index()
SP2011.drop(['index'],axis=1,inplace=True)

# ESG_SP Value for 2012-12-31 (Year 2012)
SP2012 = pd.DataFrame()
SP2012['Company_Code'] = dfs[0]['Company_Code'] 
SP2012['Date'] = '2012-12-31'
order = ['Date','Company_Code']
SP2012 = SP2012[order]

for n in range(len(filenames)):
  SP2012[dfnames[n]] = dfs[n][dfnames[n]+'12']

SP2012 = SP2012.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SP2012 = SP2012.reset_index()
SP2012.drop(['index'],axis=1,inplace=True)

# ESG_SP Value for 2013-12-31 (Year 2013)
SP2013 = pd.DataFrame()
SP2013['Company_Code'] = dfs[0]['Company_Code'] 
SP2013['Date'] = '2013-12-31'
order = ['Date','Company_Code']
SP2013 = SP2013[order]

for n in range(len(filenames)):
  SP2013[dfnames[n]] = dfs[n][dfnames[n]+'13']

SP2013 = SP2013.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SP2013 = SP2013.reset_index()
SP2013.drop(['index'],axis=1,inplace=True)

# ESG_SP Value for 2014-12-31 (Year 2014)
SP2014 = pd.DataFrame()
SP2014['Company_Code'] = dfs[0]['Company_Code'] 
SP2014['Date'] = '2014-12-31'
order = ['Date','Company_Code']
SP2014 = SP2014[order]

for n in range(len(filenames)):
  SP2014[dfnames[n]] = dfs[n][dfnames[n]+'14']

SP2014 = SP2014.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SP2014 = SP2014.reset_index()
SP2014.drop(['index'],axis=1,inplace=True)

# ESG_SP Value for 2015-12-31 (Year 2015)
SP2015 = pd.DataFrame()
SP2015['Company_Code'] = dfs[0]['Company_Code'] 
SP2015['Date'] = '2015-12-31'
order = ['Date','Company_Code']
SP2015 = SP2015[order]

for n in range(len(filenames)):
  SP2015[dfnames[n]] = dfs[n][dfnames[n]+'15']

SP2015 = SP2015.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SP2015 = SP2015.reset_index()
SP2015.drop(['index'],axis=1,inplace=True)

# ESG_SP Value for 2016-12-30 (Year 2016)
SP2016 = pd.DataFrame()
SP2016['Company_Code'] = dfs[0]['Company_Code'] 
SP2016['Date'] = '2016-12-30'
order = ['Date','Company_Code']
SP2016 = SP2016[order]

for n in range(len(filenames)):
  SP2016[dfnames[n]] = dfs[n][dfnames[n]+'16']

SP2016 = SP2016.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SP2016 = SP2016.reset_index()
SP2016.drop(['index'],axis=1,inplace=True)

# ESG_SP Value for 2017-12-29 (Year 2017)
SP2017 = pd.DataFrame()
SP2017['Company_Code'] = dfs[0]['Company_Code'] 
SP2017['Date'] = '2017-12-29'
order = ['Date','Company_Code']
SP2017 = SP2017[order]

for n in range(len(filenames)):
  SP2017[dfnames[n]] = dfs[n][dfnames[n]+'17']

SP2017 = SP2017.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SP2017 = SP2017.reset_index()
SP2017.drop(['index'],axis=1,inplace=True)

# ESG_SP Value for 2018-12-31 (Year 2018)
SP2018 = pd.DataFrame()
SP2018['Company_Code'] = dfs[0]['Company_Code'] 
SP2018['Date'] = '2018-12-31'
order = ['Date','Company_Code']
SP2018 = SP2018[order]

for n in range(len(filenames)):
  SP2018[dfnames[n]] = dfs[n][dfnames[n]+'18']

SP2018 = SP2018.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SP2018 = SP2018.reset_index()
SP2018.drop(['index'],axis=1,inplace=True)

# ESG_SP Value for 2019-12-31 (Year 2019)
SP2019 = pd.DataFrame()
SP2019['Company_Code'] = dfs[0]['Company_Code'] 
SP2019['Date'] = '2019-12-31'
order = ['Date','Company_Code']
SP2019 = SP2019[order]

for n in range(len(filenames)):
  SP2019[dfnames[n]] = dfs[n][dfnames[n]+'19']

SP2019 = SP2019.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SP2019 = SP2019.reset_index()
SP2019.drop(['index'],axis=1,inplace=True)

# ESG_SP Value for 2020-12-31 (Year 2020)
SP2020 = pd.DataFrame()
SP2020['Company_Code'] = dfs[0]['Company_Code'] 
SP2020['Date'] = '2020-12-31'
order = ['Date','Company_Code']
SP2020 = SP2020[order]

for n in range(len(filenames)):
  SP2020[dfnames[n]] = dfs[n][dfnames[n]+'20']

SP2020 = SP2020.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SP2020 = SP2020.reset_index()
SP2020.drop(['index'],axis=1,inplace=True)

ESG_S_P_Total = pd.concat([SP2011,SP2012,SP2013,SP2014,SP2015,SP2016,SP2017,SP2018,SP2019,SP2020])
ESG_S_P_Total = ESG_S_P_Total.reset_index()
ESG_S_P_Total.drop(['index'],axis=1,inplace=True)
ESG_S_P_Total
# Out:
#             Date Company_Code  ... S_P_Tobacco_Revenues S_P_Tobacco
# 0     2011-12-30          A.N  ...                  NaN       False
# 1     2011-12-30        AAP.N  ...                  NaN       False
# 2     2011-12-30      AAPL.OQ  ...                  NaN       False
# 3     2011-12-30        ABC.N  ...                  NaN       False
# 4     2011-12-30      ABMD.OQ  ...                  NaN         NaN
# ...          ...          ...  ...                  ...         ...
# 4545  2020-12-31      XRAY.OQ  ...                  NaN       False
# 4546  2020-12-31        YUM.N  ...                  NaN       False
# 4547  2020-12-31        ZBH.N  ...                  NaN       False
# 4548  2020-12-31      ZBRA.OQ  ...                  NaN       False
# 4549  2020-12-31      ZION.OQ  ...                  NaN       False
#
# [4550 rows x 64 columns]

# %% [markdown]
# ## For SHR Data, Create ESG_S_HR_Total

# %%
local_path = r'/content/drive/My Drive/ESG_Data/S_Human_Rights'
filenames = glob.glob(local_path + "/*.xlsx")

dfnames = list()

for i in range(len(filenames)):
  dfnames.append(os.path.basename(filenames[i]))
  dfnames[i] = dfnames[i][:-5]

dfs = [pd.read_excel(filename) for filename in filenames]
for m in range(len(filenames)):
  #print(dfs[m].columns)
  dfs[m].columns=['Company_Code','Company_Name',dfnames[m]+'11', dfnames[m]+'12', dfnames[m]+'13', dfnames[m]+'14', dfnames[m]+'15', dfnames[m]+'16', dfnames[m]+'17', dfnames[m]+'18', dfnames[m]+'19', dfnames[m]+'20']
  dfs[m].drop(dfs[m].head(2).index,inplace=True)
  dfs[m] = dfs[m].drop(columns=['Company_Name'])
  dfs[m] = dfs[m].reset_index()
  dfs[m].drop(['index'],axis=1,inplace=True)

# %%
# ESG_SHR Value for 2011-12-30 (Year 2011)
SHR2011 = pd.DataFrame()
SHR2011['Company_Code'] = dfs[0]['Company_Code'] 
SHR2011['Date'] = '2011-12-30'
order = ['Date','Company_Code']
SHR2011 = SHR2011[order]

for n in range(len(filenames)):
  SHR2011[dfnames[n]] = dfs[n][dfnames[n]+'11']

SHR2011 = SHR2011.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SHR2011 = SHR2011.reset_index()
SHR2011.drop(['index'],axis=1,inplace=True)

# ESG_SHR Value for 2012-12-31 (Year 2012)
SHR2012 = pd.DataFrame()
SHR2012['Company_Code'] = dfs[0]['Company_Code'] 
SHR2012['Date'] = '2012-12-31'
order = ['Date','Company_Code']
SHR2012 = SHR2012[order]

for n in range(len(filenames)):
  SHR2012[dfnames[n]] = dfs[n][dfnames[n]+'12']

SHR2012 = SHR2012.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SHR2012 = SHR2012.reset_index()
SHR2012.drop(['index'],axis=1,inplace=True)

# ESG_SHR Value for 2013-12-31 (Year 2013)
SHR2013 = pd.DataFrame()
SHR2013['Company_Code'] = dfs[0]['Company_Code'] 
SHR2013['Date'] = '2013-12-31'
order = ['Date','Company_Code']
SHR2013 = SHR2013[order]

for n in range(len(filenames)):
  SHR2013[dfnames[n]] = dfs[n][dfnames[n]+'13']

SHR2013 = SHR2013.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SHR2013 = SHR2013.reset_index()
SHR2013.drop(['index'],axis=1,inplace=True)

# ESG_SHR Value for 2014-12-31 (Year 2014)
SHR2014 = pd.DataFrame()
SHR2014['Company_Code'] = dfs[0]['Company_Code'] 
SHR2014['Date'] = '2014-12-31'
order = ['Date','Company_Code']
SHR2014 = SHR2014[order]

for n in range(len(filenames)):
  SHR2014[dfnames[n]] = dfs[n][dfnames[n]+'14']

SHR2014 = SHR2014.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SHR2014 = SHR2014.reset_index()
SHR2014.drop(['index'],axis=1,inplace=True)

# ESG_SHR Value for 2015-12-31 (Year 2015)
SHR2015 = pd.DataFrame()
SHR2015['Company_Code'] = dfs[0]['Company_Code'] 
SHR2015['Date'] = '2015-12-31'
order = ['Date','Company_Code']
SHR2015 = SHR2015[order]

for n in range(len(filenames)):
  SHR2015[dfnames[n]] = dfs[n][dfnames[n]+'15']

SHR2015 = SHR2015.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SHR2015 = SHR2015.reset_index()
SHR2015.drop(['index'],axis=1,inplace=True)

# ESG_SHR Value for 2016-12-30 (Year 2016)
SHR2016 = pd.DataFrame()
SHR2016['Company_Code'] = dfs[0]['Company_Code'] 
SHR2016['Date'] = '2016-12-30'
order = ['Date','Company_Code']
SHR2016 = SHR2016[order]

for n in range(len(filenames)):
  SHR2016[dfnames[n]] = dfs[n][dfnames[n]+'16']

SHR2016 = SHR2016.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SHR2016 = SHR2016.reset_index()
SHR2016.drop(['index'],axis=1,inplace=True)

# ESG_SHR Value for 2017-12-29 (Year 2017)
SHR2017 = pd.DataFrame()
SHR2017['Company_Code'] = dfs[0]['Company_Code'] 
SHR2017['Date'] = '2017-12-29'
order = ['Date','Company_Code']
SHR2017 = SHR2017[order]

for n in range(len(filenames)):
  SHR2017[dfnames[n]] = dfs[n][dfnames[n]+'17']

SHR2017 = SHR2017.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SHR2017 = SHR2017.reset_index()
SHR2017.drop(['index'],axis=1,inplace=True)

# ESG_SHR Value for 2018-12-31 (Year 2018)
SHR2018 = pd.DataFrame()
SHR2018['Company_Code'] = dfs[0]['Company_Code'] 
SHR2018['Date'] = '2018-12-31'
order = ['Date','Company_Code']
SHR2018 = SHR2018[order]

for n in range(len(filenames)):
  SHR2018[dfnames[n]] = dfs[n][dfnames[n]+'18']

SHR2018 = SHR2018.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SHR2018 = SHR2018.reset_index()
SHR2018.drop(['index'],axis=1,inplace=True)

# ESG_SHR Value for 2019-12-31 (Year 2019)
SHR2019 = pd.DataFrame()
SHR2019['Company_Code'] = dfs[0]['Company_Code'] 
SHR2019['Date'] = '2019-12-31'
order = ['Date','Company_Code']
SHR2019 = SHR2019[order]

for n in range(len(filenames)):
  SHR2019[dfnames[n]] = dfs[n][dfnames[n]+'19']

SHR2019 = SHR2019.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SHR2019 = SHR2019.reset_index()
SHR2019.drop(['index'],axis=1,inplace=True)

# ESG_SHR Value for 2020-12-31 (Year 2020)
SHR2020 = pd.DataFrame()
SHR2020['Company_Code'] = dfs[0]['Company_Code'] 
SHR2020['Date'] = '2020-12-31'
order = ['Date','Company_Code']
SHR2020 = SHR2020[order]

for n in range(len(filenames)):
  SHR2020[dfnames[n]] = dfs[n][dfnames[n]+'20']

SHR2020 = SHR2020.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SHR2020 = SHR2020.reset_index()
SHR2020.drop(['index'],axis=1,inplace=True)

ESG_S_HR_Total = pd.concat([SHR2011,SHR2012,SHR2013,SHR2014,SHR2015,SHR2016,SHR2017,SHR2018,SHR2019,SHR2020])
ESG_S_HR_Total = ESG_S_HR_Total.reset_index()
ESG_S_HR_Total.drop(['index'],axis=1,inplace=True)
ESG_S_HR_Total
# Out:
#             Date  ... S_HR_Recent_Human_Rights_Controversies
# 0     2011-12-30  ...                                    NaN
# 1     2011-12-30  ...                                    NaN
# 2     2011-12-30  ...                                    NaN
# 3     2011-12-30  ...                                    NaN
# 4     2011-12-30  ...                                    NaN
# ...          ...  ...                                    ...
# 4545  2020-12-31  ...                                    NaN
# 4546  2020-12-31  ...                                    NaN
# 4547  2020-12-31  ...                                    NaN
# 4548  2020-12-31  ...                                    NaN
# 4549  2020-12-31  ...                                    NaN
#
# [4550 rows x 16 columns]

# %% [markdown]
# ## For SW Data, Create ESG_S_W_Total

# %%
local_path = r'/content/drive/My Drive/ESG_Data/S_Workforce'
filenames = glob.glob(local_path + "/*.xlsx")

dfnames = list()

for i in range(len(filenames)):
  dfnames.append(os.path.basename(filenames[i]))
  dfnames[i] = dfnames[i][:-5]

dfs = [pd.read_excel(filename) for filename in filenames]
for m in range(len(filenames)):
  #print(dfs[m].columns)
  dfs[m].columns=['Company_Code','Company_Name',dfnames[m]+'11', dfnames[m]+'12', dfnames[m]+'13', dfnames[m]+'14', dfnames[m]+'15', dfnames[m]+'16', dfnames[m]+'17', dfnames[m]+'18', dfnames[m]+'19', dfnames[m]+'20']
  dfs[m].drop(dfs[m].head(2).index,inplace=True)
  dfs[m] = dfs[m].drop(columns=['Company_Name'])
  dfs[m] = dfs[m].reset_index()
  dfs[m].drop(['index'],axis=1,inplace=True)

# %%
n# ESG_SW Value for 2011-12-30 (Year 2011)
SW2011 = pd.DataFrame()
SW2011['Company_Code'] = dfs[0]['Company_Code'] 
SW2011['Date'] = '2011-12-30'
order = ['Date','Company_Code']
SW2011 = SW2011[order]

for n in range(len(filenames)):
  SW2011[dfnames[n]] = dfs[n][dfnames[n]+'11']

SW2011 = SW2011.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SW2011 = SW2011.reset_index()
SW2011.drop(['index'],axis=1,inplace=True)

# ESG_SW Value for 2012-12-31 (Year 2012)
SW2012 = pd.DataFrame()
SW2012['Company_Code'] = dfs[0]['Company_Code'] 
SW2012['Date'] = '2012-12-31'
order = ['Date','Company_Code']
SW2012 = SW2012[order]

for n in range(len(filenames)):
  SW2012[dfnames[n]] = dfs[n][dfnames[n]+'12']

SW2012 = SW2012.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SW2012 = SW2012.reset_index()
SW2012.drop(['index'],axis=1,inplace=True)

# ESG_SW Value for 2013-12-31 (Year 2013)
SW2013 = pd.DataFrame()
SW2013['Company_Code'] = dfs[0]['Company_Code'] 
SW2013['Date'] = '2013-12-31'
order = ['Date','Company_Code']
SW2013 = SW2013[order]

for n in range(len(filenames)):
  SW2013[dfnames[n]] = dfs[n][dfnames[n]+'13']

SW2013 = SW2013.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SW2013 = SW2013.reset_index()
SW2013.drop(['index'],axis=1,inplace=True)

# ESG_SW Value for 2014-12-31 (Year 2014)
SW2014 = pd.DataFrame()
SW2014['Company_Code'] = dfs[0]['Company_Code'] 
SW2014['Date'] = '2014-12-31'
order = ['Date','Company_Code']
SW2014 = SW2014[order]

for n in range(len(filenames)):
  SW2014[dfnames[n]] = dfs[n][dfnames[n]+'14']

SW2014 = SW2014.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SW2014 = SW2014.reset_index()
SW2014.drop(['index'],axis=1,inplace=True)

# ESG_SW Value for 2015-12-31 (Year 2015)
SW2015 = pd.DataFrame()
SW2015['Company_Code'] = dfs[0]['Company_Code'] 
SW2015['Date'] = '2015-12-31'
order = ['Date','Company_Code']
SW2015 = SW2015[order]

for n in range(len(filenames)):
  SW2015[dfnames[n]] = dfs[n][dfnames[n]+'15']

SW2015 = SW2015.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SW2015 = SW2015.reset_index()
SW2015.drop(['index'],axis=1,inplace=True)

# ESG_SW Value for 2016-12-30 (Year 2016)
SW2016 = pd.DataFrame()
SW2016['Company_Code'] = dfs[0]['Company_Code'] 
SW2016['Date'] = '2016-12-30'
order = ['Date','Company_Code']
SW2016 = SW2016[order]

for n in range(len(filenames)):
  SW2016[dfnames[n]] = dfs[n][dfnames[n]+'16']

SW2016 = SW2016.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SW2016 = SW2016.reset_index()
SW2016.drop(['index'],axis=1,inplace=True)

# ESG_SW Value for 2017-12-29 (Year 2017)
SW2017 = pd.DataFrame()
SW2017['Company_Code'] = dfs[0]['Company_Code'] 
SW2017['Date'] = '2017-12-29'
order = ['Date','Company_Code']
SW2017 = SW2017[order]

for n in range(len(filenames)):
  SW2017[dfnames[n]] = dfs[n][dfnames[n]+'17']

SW2017 = SW2017.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SW2017 = SW2017.reset_index()
SW2017.drop(['index'],axis=1,inplace=True)

# ESG_SW Value for 2018-12-31 (Year 2018)
SW2018 = pd.DataFrame()
SW2018['Company_Code'] = dfs[0]['Company_Code'] 
SW2018['Date'] = '2018-12-31'
order = ['Date','Company_Code']
SW2018 = SW2018[order]

for n in range(len(filenames)):
  SW2018[dfnames[n]] = dfs[n][dfnames[n]+'18']

SW2018 = SW2018.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SW2018 = SW2018.reset_index()
SW2018.drop(['index'],axis=1,inplace=True)

# ESG_SW Value for 2019-12-31 (Year 2019)
SW2019 = pd.DataFrame()
SW2019['Company_Code'] = dfs[0]['Company_Code'] 
SW2019['Date'] = '2019-12-31'
order = ['Date','Company_Code']
SW2019 = SW2019[order]

for n in range(len(filenames)):
  SW2019[dfnames[n]] = dfs[n][dfnames[n]+'19']

SW2019 = SW2019.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SW2019 = SW2019.reset_index()
SW2019.drop(['index'],axis=1,inplace=True)

# ESG_SW Value for 2020-12-31 (Year 2020)
SW2020 = pd.DataFrame()
SW2020['Company_Code'] = dfs[0]['Company_Code'] 
SW2020['Date'] = '2020-12-31'
order = ['Date','Company_Code']
SW2020 = SW2020[order]

for n in range(len(filenames)):
  SW2020[dfnames[n]] = dfs[n][dfnames[n]+'20']

SW2020 = SW2020.drop(index=[1,   4,  26,  29,  36,  44,  77,  85,  89, 116, 118, 122, 125,
            139, 158, 166, 174, 176, 177, 188, 189, 193, 202, 214, 219, 220,
            223, 238, 244, 245, 260, 261, 265, 288, 312, 324, 332, 335, 344,
            345, 353, 355, 382, 386, 424, 448, 452, 490, 499, 504])

SW2020 = SW2020.reset_index()
SW2020.drop(['index'],axis=1,inplace=True)

ESG_S_W_Total = pd.concat([SW2011,SW2012,SW2013,SW2014,SW2015,SW2016,SW2017,SW2018,SW2019,SW2020])
ESG_S_W_Total = ESG_S_W_Total.reset_index()
ESG_S_W_Total.drop(['index'],axis=1,inplace=True)
ESG_S_W_Total
# Out:
#             Date Company_Code  ... S_W_Women_Employees S_W_Women_Managers
# 0     2011-12-30          A.N  ...                  33               22.8
# 1     2011-12-30        AAP.N  ...                 NaN                NaN
# 2     2011-12-30      AAPL.OQ  ...                 NaN                NaN
# 3     2011-12-30        ABC.N  ...                 NaN                NaN
# 4     2011-12-30      ABMD.OQ  ...                 NaN                NaN
# ...          ...          ...  ...                 ...                ...
# 4545  2020-12-31      XRAY.OQ  ...                 NaN                NaN
# 4546  2020-12-31        YUM.N  ...                 NaN                 48
# 4547  2020-12-31        ZBH.N  ...                 NaN                NaN
# 4548  2020-12-31      ZBRA.OQ  ...                 NaN                NaN
# 4549  2020-12-31      ZION.OQ  ...                58.7               54.1
#
# [4550 rows x 86 columns]

# %% [markdown]
# ## Combine All, Deal with NaN, Create final_Full_ESG_Indicators

# %%
ESG_Total_1 = pd.merge(ESG_E_E_Total, ESG_E_I_Total, on=['Date', 'Company_Code'])
ESG_Total_2 = pd.merge(ESG_Total_1, ESG_E_RU_Total , on=['Date', 'Company_Code'])
ESG_Total_3 = pd.merge(ESG_Total_2, ESG_G_C_Total , on=['Date', 'Company_Code'])
ESG_Total_4 = pd.merge(ESG_Total_3, ESG_G_M_Total , on=['Date', 'Company_Code'])
ESG_Total_5 = pd.merge(ESG_Total_4, ESG_G_S_Total , on=['Date', 'Company_Code'])
ESG_Total_6 = pd.merge(ESG_Total_5, ESG_S_C_Total, on=['Date', 'Company_Code'])
ESG_Total_7 = pd.merge(ESG_Total_6, ESG_S_HR_Total , on=['Date', 'Company_Code'])
ESG_Total_8 = pd.merge(ESG_Total_7, ESG_S_P_Total , on=['Date', 'Company_Code'])
ESG_Total = pd.merge(ESG_Total_8, ESG_S_W_Total , on=['Date', 'Company_Code'])
ESG_Total
# Out:
#             Date Company_Code  ... S_W_Women_Employees S_W_Women_Managers
# 0     2011-12-30          A.N  ...                  33               22.8
# 1     2011-12-30        AAP.N  ...                 NaN                NaN
# 2     2011-12-30      AAPL.OQ  ...                 NaN                NaN
# 3     2011-12-30        ABC.N  ...                 NaN                NaN
# 4     2011-12-30      ABMD.OQ  ...                 NaN                NaN
# ...          ...          ...  ...                 ...                ...
# 4545  2020-12-31      XRAY.OQ  ...                 NaN                NaN
# 4546  2020-12-31        YUM.N  ...                 NaN                 48
# 4547  2020-12-31        ZBH.N  ...                 NaN                NaN
# 4548  2020-12-31      ZBRA.OQ  ...                 NaN                NaN
# 4549  2020-12-31      ZION.OQ  ...                58.7               54.1
#
# [4550 rows x 482 columns]

# %%
# ESG_Total_11 = ESG_Total[ESG_Total['Date']=='2011-12-30']
# ESG_Total.iloc[:,2].isna().sum() / len(ESG_Total)
percentNaN = list()
for i1 in range(2, 482):
  percentNaN.append(ESG_Total.iloc[:,i1].isna().sum() / len(ESG_Total))
percentNaN = pd.Series(percentNaN)
print(percentNaN)
drop_col_index = percentNaN.index[np.where(percentNaN>0.05)[0]]
drop_col_index

# for i in range(len(drop_col_index)):
#   drop_col_index[i] = drop_col_index[i] + 2

# drop_col_index

# countNaN11.columns['PercNaN']
# print(ESG_Total_11.iloc[:,2].dropna().count())
# Out:
# 0      0.958022
# 1      0.976044
# 2      0.029451
# 3      0.885495
# 4      1.000000
#          ...
# 475    0.934725
# 476    0.976923
# 477    0.985495
# 478    0.595165
# 479    0.721978
# Length: 480, dtype: float64
# Int64Index([  0,   1,   3,   4,   6,   7,   8,   9,  11,  12,
#             ...
#             469, 470, 471, 472, 473, 475, 476, 477, 478, 479],
#            dtype='int64', length=270)

# %%
# Find all the company contain full data
total_try = ESG_Total
total_try.drop(total_try.columns[drop_col_index+2], axis=1, inplace=True)

total_try11 = total_try[total_try['Date']=='2011-12-30']
total_try11 = total_try11.dropna()
total_try11 = total_try11.reset_index()
total_try11.drop(['index'],axis=1,inplace=True)

total_try12 = total_try[total_try['Date']=='2012-12-31']
total_try12 = total_try12.dropna()
total_try12 = total_try12.reset_index()
total_try12.drop(['index'],axis=1,inplace=True)

total_try13 = total_try[total_try['Date']=='2013-12-31']
total_try13 = total_try13.dropna()
total_try13 = total_try13.reset_index()
total_try13.drop(['index'],axis=1,inplace=True)

total_try14 = total_try[total_try['Date']=='2014-12-31']
total_try14 = total_try14.dropna()
total_try14 = total_try14.reset_index()
total_try14.drop(['index'],axis=1,inplace=True)

total_try15 = total_try[total_try['Date']=='2015-12-31']
total_try15 = total_try15.dropna()
total_try15 = total_try15.reset_index()
total_try15.drop(['index'],axis=1,inplace=True)

total_try16 = total_try[total_try['Date']=='2016-12-30']
total_try16 = total_try16.dropna()
total_try16 = total_try16.reset_index()
total_try16.drop(['index'],axis=1,inplace=True)

total_try17 = total_try[total_try['Date']=='2017-12-29']
total_try17 = total_try17.dropna()
total_try17 = total_try17.reset_index()
total_try17.drop(['index'],axis=1,inplace=True)

total_try18 = total_try[total_try['Date']=='2018-12-31']
total_try18 = total_try18.dropna()
total_try18 = total_try18.reset_index()
total_try18.drop(['index'],axis=1,inplace=True)

total_try19 = total_try[total_try['Date']=='2019-12-31']
total_try19 = total_try19.dropna()
total_try19 = total_try19.reset_index()
total_try19.drop(['index'],axis=1,inplace=True)

total_try20 = total_try[total_try['Date']=='2020-12-31']
total_try20 = total_try20.dropna()
total_try20 = total_try20.reset_index()
total_try20.drop(['index'],axis=1,inplace=True)


try111 = pd.merge(total_try11, total_try12, on=['Company_Code'])
try112 = pd.merge(try111, total_try13, on=['Company_Code'])
try113 = pd.merge(try112, total_try14, on=['Company_Code'])
try114 = pd.merge(try113, total_try15, on=['Company_Code'])
try115 = pd.merge(try114, total_try16, on=['Company_Code'])
try116 = pd.merge(try115, total_try17, on=['Company_Code'])
try117 = pd.merge(try116, total_try18, on=['Company_Code'])
try118 = pd.merge(try117, total_try19, on=['Company_Code'])
try_last = pd.merge(try118, total_try20, on=['Company_Code'])

full_data_company = try_last['Company_Code']
full_data_company
# Out:
# 0          A.N
# 1      AAPL.OQ
# 2        ABT.N
# 3        ADM.N
# 4      ADSK.OQ
#         ...
# 224     XEL.OQ
# 225      XOM.N
# 226      ZBH.N
# 227    ZBRA.OQ
# 228    ZION.OQ
# Name: Company_Code, Length: 229, dtype: object

# %%
full_data_company.to_csv("/content/drive/My Drive/ESG_Data/Output/stock_pool.csv")

# %%
# total_try is the indicators contain value > 95%
final_need_11 = total_try[total_try['Date']=='2011-12-30']
final_need_11 = pd.merge(final_need_11, full_data_company, on=['Company_Code'])

final_need_12 = total_try[total_try['Date']=='2012-12-31']
final_need_12 = pd.merge(final_need_12, full_data_company, on=['Company_Code'])

final_need_13 = total_try[total_try['Date']=='2013-12-31']
final_need_13 = pd.merge(final_need_13, full_data_company, on=['Company_Code'])

final_need_14 = total_try[total_try['Date']=='2014-12-31']
final_need_14 = pd.merge(final_need_14, full_data_company, on=['Company_Code'])

final_need_15 = total_try[total_try['Date']=='2015-12-31']
final_need_15 = pd.merge(final_need_15, full_data_company, on=['Company_Code'])

final_need_16 = total_try[total_try['Date']=='2016-12-30']
final_need_16 = pd.merge(final_need_16, full_data_company, on=['Company_Code'])

final_need_17 = total_try[total_try['Date']=='2017-12-29']
final_need_17 = pd.merge(final_need_17, full_data_company, on=['Company_Code'])

final_need_18 = total_try[total_try['Date']=='2018-12-31']
final_need_18 = pd.merge(final_need_18, full_data_company, on=['Company_Code'])

final_need_19 = total_try[total_try['Date']=='2019-12-31']
final_need_19 = pd.merge(final_need_19, full_data_company, on=['Company_Code'])

final_need_20 = total_try[total_try['Date']=='2020-12-31']
final_need_20 = pd.merge(final_need_20, full_data_company, on=['Company_Code'])

final_Full_ESG_Indicators = pd.concat([final_need_11,final_need_12,final_need_13,final_need_14,final_need_15,final_need_16,final_need_17,final_need_18,final_need_19,final_need_20])
final_Full_ESG_Indicators
# Out:
#            Date  ... S_W_Wages_Working_Condition_Controversies
# 0    2011-12-30  ...                                     False
# 1    2011-12-30  ...                                      True
# 2    2011-12-30  ...                                     False
# 3    2011-12-30  ...                                      True
# 4    2011-12-30  ...                                     False
# ..          ...  ...                                       ...
# 224  2020-12-31  ...                                     False
# 225  2020-12-31  ...                                      True
# 226  2020-12-31  ...                                     False
# 227  2020-12-31  ...                                     False
# 228  2020-12-31  ...                                     False
#
# [2290 rows x 212 columns]

# %%
pd.set_option('display.max_columns', None)
final_Full_ESG_Indicators
# Out:
#            Date Company_Code E_E_Biodiversity_Impact_Reduction  \
# 0    2011-12-30          A.N                              True
# 1    2011-12-30      AAPL.OQ                             False
# 2    2011-12-30        ABT.N                             False
# 3    2011-12-30        ADM.N                             False
# 4    2011-12-30      ADSK.OQ                             False
# ..          ...          ...                               ...
# 224  2020-12-31       XEL.OQ                              True
# 225  2020-12-31        XOM.N                              True
# 226  2020-12-31        ZBH.N                             False
# 227  2020-12-31      ZBRA.OQ                             False
# 228  2020-12-31      ZION.OQ                             False
#
#     E_E_Climate_Change_Commercial_Risks_Opportunities  \
# 0                                                True
# 1                                                True
# ...

# %% [markdown]
# ## Change some data type in final_Full_ESG_Indicators into values

# %%
pd.set_option('display.max_columns', None)
final_Full_ESG_Indicators
# Out:
#            Date Company_Code E_E_Biodiversity_Impact_Reduction  \
# 0    2011-12-30          A.N                              True
# 1    2011-12-30      AAPL.OQ                             False
# 2    2011-12-30        ABT.N                             False
# 3    2011-12-30        ADM.N                             False
# 4    2011-12-30      ADSK.OQ                             False
# ..          ...          ...                               ...
# 224  2020-12-31       XEL.OQ                              True
# 225  2020-12-31        XOM.N                              True
# 226  2020-12-31        ZBH.N                             False
# 227  2020-12-31      ZBRA.OQ                             False
# 228  2020-12-31      ZION.OQ                             False
#
#     E_E_Climate_Change_Commercial_Risks_Opportunities  \
# 0                                                True
# 1                                                True
# ...

# %%
# final_Full_ESG_Indicators.columns.get_loc('G_C_ESG_Period_Last_Update_Date')

# %%
for iii in range(2,4):
  final_Full_ESG_Indicators.iloc[:,iii] = final_Full_ESG_Indicators.iloc[:,iii].astype(int)

for iii in range(5,12):
  final_Full_ESG_Indicators.iloc[:,iii] = final_Full_ESG_Indicators.iloc[:,iii].astype(int)

for iii in range(13,60):
  final_Full_ESG_Indicators.iloc[:,iii] = final_Full_ESG_Indicators.iloc[:,iii].astype(int)

for iii in range(61,81):
  final_Full_ESG_Indicators.iloc[:,iii] = final_Full_ESG_Indicators.iloc[:,iii].astype(int)

for iii in range(82,212):
  final_Full_ESG_Indicators.iloc[:,iii] = final_Full_ESG_Indicators.iloc[:,iii].astype(int)


# for iii in range(13,212):
#   final_Full_ESG_Indicators.iloc[:,iii] = final_Full_ESG_Indicators.iloc[:,iii].astype(int)

final_Full_ESG_Indicators = final_Full_ESG_Indicators.drop('G_C_ESG_Period_Last_Update_Date', axis=1)

final_Full_ESG_Indicators = pd.get_dummies(final_Full_ESG_Indicators, columns = ['E_E_Co2_Estimation_Method'])

# for u in final_Full_ESG_Indicators.columns:
#     if final_Full_ESG_Indicators[u].dtype == bool:
#         final_Full_ESG_Indicators[u] = final_Full_ESG_Indicators[u].astype('int')

# final_Full_ESG_Indicators

# %%
for aaa in range(len(final_Full_ESG_Indicators['E_E_ISO_14000_or_EMS'])):
  if final_Full_ESG_Indicators.iloc[aaa,11] == 'ISO 14000':
    final_Full_ESG_Indicators.iloc[aaa,11] = 1
  else:
      final_Full_ESG_Indicators.iloc[aaa,11] = 0

for bbb in range(len(final_Full_ESG_Indicators['G_M_Board_Structure_Type'])):
  if final_Full_ESG_Indicators.iloc[bbb,79] == 'Unitary':
    final_Full_ESG_Indicators.iloc[bbb,79] = 1
  else:
      final_Full_ESG_Indicators.iloc[bbb,79] = 0

# %%
final_Full_ESG_Indicators = final_Full_ESG_Indicators.reset_index()
final_Full_ESG_Indicators.drop(['index'],axis=1,inplace=True)

# %% [markdown]
# # Full Indicators Value

# %%
final_Full_ESG_Indicators
# Out:
#             Date Company_Code  E_E_Biodiversity_Impact_Reduction  \
# 0     2011-12-30          A.N                                  1
# 1     2011-12-30      AAPL.OQ                                  0
# 2     2011-12-30        ABT.N                                  0
# 3     2011-12-30        ADM.N                                  0
# 4     2011-12-30      ADSK.OQ                                  0
# ...          ...          ...                                ...
# 2285  2020-12-31       XEL.OQ                                  1
# 2286  2020-12-31        XOM.N                                  1
# 2287  2020-12-31        ZBH.N                                  0
# 2288  2020-12-31      ZBRA.OQ                                  0
# 2289  2020-12-31      ZION.OQ                                  0
#
#       E_E_Climate_Change_Commercial_Risks_Opportunities  \
# 0                                                     1
# 1                                                     1
# ...

# %%
# final_Full_ESG_Indicators.to_csv("/content/drive/My Drive/ESG_Data/Output/final_Full_ESG_Indicators.csv")
